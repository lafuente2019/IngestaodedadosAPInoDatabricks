# %%
# Instala o pacote necessário para leitura de variáveis armazenadas em arquivo .env,
# utilizado como alternativa ao dbutils.secrets (não disponível na versão gratuita do Databricks)
# %pip install python-dotenv

# %%
# Importa as bibliotecas
from dotenv import load_dotenv
import os

# %%
# 🔹 Carrega as variáveis definidas no arquivo .env
load_dotenv()

# %%
# Lista de ações que queremos monitorar
tickets = ["PETR4","VALE3","ITUB4","BBDC4","ABEV3"]

# %%
# 🔹 Recupera a chave da API
API_KEY = os.getenv("ALPHAVANTAGE_API_KEY")

# %%
# Teste simples (não imprime a chave real)
if API_KEY:
    print("✅ Chave carregada com sucesso!")
else:
    print("⚠️ Chave não encontrada. Verifique se o arquivo .env está no mesmo diretório.")

# %%
# %sql
-- Criação do schema (camada Bronze) dentro do catálogo 'workspace'.
-- O Unity Catalog não permite definir LOCATION manualmente na edição gratuita,
-- então o armazenamento será gerenciado automaticamente pelo Databricks.
CREATE SCHEMA IF NOT EXISTS workspace.bronze
COMMENT 'Camada Bronze para armazenamento de dados brutos';
