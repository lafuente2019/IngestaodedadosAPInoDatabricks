# %%
# %run /Workspace/Users/valterlafuentejunior@gmail.com/IngestaodedadosAPInoDatabricks/Config/config

# %%
df_cotacoes = spark.table("workspace.bronze.cotacoes_yfinance")

# %%
df_cotacoes.display()

# %%
df_cotacoes.createOrReplaceTempView("vw_cotacoes")

# %%
spark.sql("""
    select ticker,
        max(data) as ultima_data,
        avg(fechamento) as media_fechamento
    from vw_cotacoes
    group by ticker       
""").display()
